# %%
import pandas as pd, numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import plotly as pt
import plotly.express as px
# %matplotlib inline
import plotly.graph_objects as go

# %%
data = pd.read_csv("ZMotorControl.csv")

# %%
data.head()
# Out:
#        Time  Distance  Z-Motor
# 0  21:57:46       0.0    49.75
# 1  21:57:46       0.0    49.75
# 2  21:57:47       0.0    49.75
# 3  21:57:47       0.0    49.75
# 4  21:57:47       0.0    49.75

# %%
fig = plt.figure(figsize=(15,7))

plt.plot(data["Distance"], label="Расстояние")
plt.plot(data["Z-Motor"], label="Мотор-Z")

plot.title('Алгоритм управления приводом - Z').set_color('black')
plot.xlabel('Количество измерении').set_color('black')
plot.ylabel('Значения величин').set_color('black')

plot.legend()
plt.savefig('z_motor_control.png')
plot.show()
